# %%
# %matplotlib inline
import numpy as np
import sys

import osh5io
import osh5def
import osh5vis
import osh5utils
import osh5dir
import matplotlib.pyplot as plt

# %%
base_directory1 = '/scratch/agrt_root/agrt0/agrt/solid_water_pol0_no_CI'
base_directory2 = '/scratch/agrt_root/agrt0/agrt/solid_water_pol0_CI'





osh5dir.runinfo(base_directory1)
osh5dir.runinfo(base_directory2)
# Out:
# DENSITY
# PHA
# ION
# run-info
# FLD
# DENSITY
# PHA
# ION
# run-info
# FLD

# %%
species = 'O'
filenum =110
field = 'e1'
iflog = False
clims = (-0.1,0.1) #(-0.02,0.02)

(field_name1,fldmap1) = osh5dir.getfieldname(base_directory1,field,species,'')
(field_name2,fldmap2) = osh5dir.getfieldname(base_directory2,field,species,'')
data1 = osh5dir.getfile(field_name1,filenum)
data2 = osh5dir.getfile(field_name2,filenum)
#(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#data2 = osh5dir.getfile(field_name,filenum)

if iflog:
    data1 = np.log10(abs(data1))
    data2 = np.log10(abs(data2))
    
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
osh5vis.osplot(data1, cmap = fldmap1,clim=clims)
plt.subplot(1, 2, 2)
osh5vis.osplot(data2, cmap = fldmap2,clim=clims)
# Out:
# (<matplotlib.image.AxesImage at 0x2b037ca4ec40>,
#  <matplotlib.colorbar.Colorbar at 0x2b037c91cdf0>)

# %% [markdown]
# #### plt.figure(figsize=(16, 6))
# plt.subplot(1, 2, 1)
# osh5vis.osplot(data1, cmap = fldmap1,clim=clims)
# plt.subplot(1, 2, 2)
# osh5vis.osplot(data2, cmap = fldmap2,clim=clims)

# %% [markdown]
# #### osh5vis.osplot(data, cmap = fldmap)#,clim=(-0.01,0.01))
# #plt.show()
# #osh5vis.osplot(data2)#, cmap = fldmap,ylim = (-40,40),clim=(0,-7))

# %%
species = 'electrons_O'
#filenum = 200
field = 'p1x1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log10(-data), cmap = fldmap)#,clim=(-0.1,0.1))
# Out:
# <ipython-input-40-4b01b6e1bbf9>:6: RuntimeWarning: divide by zero encountered in log10
#   osh5vis.osplot(np.log10(-data), cmap = fldmap)#,clim=(-0.1,0.1))
# (<matplotlib.image.AxesImage at 0x2ae6615b0250>,
#  <matplotlib.colorbar.Colorbar at 0x2ae6617a9f40>)

# %%
species = 'electrons_O'
filenum = 500
field = 'e1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(data, cmap = fldmap,clim=(-0.02,0.02))
# Out:
# (<matplotlib.image.AxesImage at 0x2ae661539ee0>,
#  <matplotlib.colorbar.Colorbar at 0x2ae65fe2f8e0>)

# %%
species = 'protons'
filenum = 500
field = 'p2p1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log10(data), cmap = fldmap)#,clim = (0,0.01))#,xlim=(-0.2,0.2),ylim=(-0.2,0.2))
# Out:
# <ipython-input-42-758ff62c56c7>:6: RuntimeWarning: divide by zero encountered in log10
#   osh5vis.osplot(np.log10(data), cmap = fldmap)#,clim = (0,0.01))#,xlim=(-0.2,0.2),ylim=(-0.2,0.2))
# (<matplotlib.image.AxesImage at 0x2ae6617cd430>,
#  <matplotlib.colorbar.Colorbar at 0x2ae661875d60>)

# %%
gamma2 = np.sum(data.data,1)

# %%
plt.plot(gamma)
plt.plot(gamma2)
plt.xlim((270,310))
# Out:
# (270.0, 310.0)

# %%
x = np.linspace(-100,100,200)
plt.plot(x,np.heaviside(x+90,0.5)*np.heaviside(90-x,0.5))
