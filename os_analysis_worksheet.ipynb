# %%
# %matplotlib inline
import numpy as np
import sys

import osh5io
import osh5def
import osh5vis
import osh5utils
import matplotlib.pyplot as plt
# Out:
# /home/agrt/pyVisOS/osh5def.py:466: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if axes is () or axes[0] is None:  # axes is none, numpy default is to reverse the order

# %%
data = osh5io.read_h5('/home/agrt/osiris_diiorio/osiris/data/beam_air/MS/FLD/e2/e2-000000.h5')
print(data)
# Out:
# e2-000000, shape: (200, 150), time:[0.] [\omega_p^{-1} ]
# axis:
#   x2: [-40.0, 40.00000000000001] c \omega_p^{-1}
#   x1: [0.0, 50.0] c \omega_p^{-1}

# %%
osh5vis.osplot(data)
# Out:
# (<matplotlib.image.AxesImage at 0x2af1f5a74e50>,
#  <matplotlib.colorbar.Colorbar at 0x2af1f5ab87f0>)
