# %%
# %matplotlib inline
import numpy as np
import sys

import osh5io
import osh5def
import osh5vis
import osh5utils
import osh5dir
import matplotlib.pyplot as plt

# %%
#base_directory = '/home/agrt/osiris_diiorio/osiris/data/beam_air_new3'
#base_directory = '/home/agrt/osiris_diiorio/osiris/data/beam_air_ppc'
#base_directory2 = '/home/agrt/osiris_diiorio/osiris/data/beam_air_ppc1'

#base_directory1 = '/home/agrt/osiris_diiorio/osiris/data/test7'
#base_directory2 = '/home/agrt/osiris_diiorio/osiris/data/test_no_secondary7'
#base_directory = '/scratch/agrt_root/agrt0/agrt/test_fld1'
#base_directory1 = '/home/agrt/osiris_diiorio/osiris/data/test_fld'


#base_directory = '/scratch/agrt_root/agrt0/agrt/beam_air_new'
#base_directory2 = '/scratch/agrt_root/agrt0/agrt/beam_air_new'
#base_directory = '/home/agrt/osiris_diiorio/osiris/data/beam_vac3'

#base_directory = '/scratch/agrt_root/agrt0/agrt/solid_water_new1'
#base_directory = '/home/agrt/osiris/data/Mario_run2'

#base_directory = '/scratch/agrt_root/agrt0/agrt/test_new2'

#base_directory = '/scratch/agrt_root/agrt1/agrt/osiris/Mario_final3'
base_directory = '/scratch/agrt_root/agrt1/agrt/osiris/Mario_brute_force2'






osh5dir.runinfo(base_directory)
# Out:
# DENSITY
# PHA
# FLD

# %%
species = 'electrons'
filenum = 90

field = 'ene'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
ene = osh5dir.getfile(field_name,filenum)
field = 'charge'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
charge = osh5dir.getfile(field_name,filenum)

Te = ene/abs(charge)

#(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#data2 = osh5dir.getfile(field_name,filenum)
plt.figure(figsize=(14,14))
#osh5vis.osplot((Te*511),aspect='equal',clim=(0.,5))
osh5vis.osplot(ene, cmap = fldmap,aspect='equal')
#plt.plot(charge.axes[1],charge[300,:],'k')
#osh5vis.osplot(charge, cmap = fldmap,aspect='equal')
#plt.contour(charge.axes[0],charge.axes[1],charge)
# Out:
# /tmp/ipykernel_318239/1398714855.py:11: RuntimeWarning: invalid value encountered in true_divide
#   Te = ene/abs(charge)
# (<matplotlib.image.AxesImage at 0x14daebe40c70>,
#  <matplotlib.colorbar.Colorbar at 0x14daebe52f70>)

# %%
osh5vis.osplot(charge+charge2, cmap = fldmap,aspect='equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1789871/279730047.py in <module>
# ----> 1 osh5vis.osplot(charge+charge2, cmap = fldmap,aspect='equal')
#
# NameError: name 'charge2' is not defined

# %%
1.4e-3/32**2/(0.002)**3
# Out:
# 170.8984375

# %%
## species = 'electrons'
filenum =120
field = 'e2'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
#(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#data2 = osh5dir.getfile(field_name,filenum)
plt.figure(figsize=(14,14))
osh5vis.osplot((data), cmap = fldmap,aspect='equal',clim=(-0.02,0.02))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_934357/2150355208.py in <module>
#       3 field = 'e2'
#       4 (field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
# ----> 5 data = osh5dir.getfile(field_name,filenum)
#       6 #(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#       7 #data2 = osh5dir.getfile(field_name,filenum)
#
# ~/pyVisOS/osh5dir.py in getfile(field_name, filenum)
#      24 # print("filename = ",filename)
#      25     #data = h5.File(filename, "r")
# ---> 26     data = osh5io.read_h5(filename)
#      27     #N = data['SIMULATION'].attrs['NX']
#      28     #axes = data['AXIS']
#
# ~/pyVisOS/osh5io.py in read_h5(filename, path, axis_name)
#     100     """
#     101     fname = filename if not path else path + '/' + filename
# --> 102     data_file = h5py.File(fname, 'r')
#     103
#     104     n_data = scan_hdf5_file_for_main_data_array(data_file)
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     442             with phil:
#     443                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 444                 fid = make_fid(name, mode, userblock_size,
#     445                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     446                                fs_persist=fs_persist, fs_threshold=fs_threshold),
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     197         if swmr and swmr_support:
#     198             flags |= h5f.ACC_SWMR_READ
# --> 199         fid = h5f.open(name, flags, fapl=fapl)
#     200     elif mode == 'r+':
#     201         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/scratch/agrt_root/agrt1/agrt/osiris/Mario_brute_force/MS/FLD/e2/e2-000120.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
species = 'ions'
field = 'p1x1'
filenum = 100
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log(np.abs(data)), cmap = fldmap)#,aspect='equal')#,clim=(-1,0))
plt.ylim(-0.002,0.002)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1160298/3822718724.py in <module>
#       3 filenum = 100
#       4 (field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
# ----> 5 data = osh5dir.getfile(field_name,filenum)
#       6 osh5vis.osplot(np.log(np.abs(data)), cmap = fldmap)#,aspect='equal')#,clim=(-1,0))
#       7 plt.ylim(-0.002,0.002)
#
# ~/pyVisOS/osh5dir.py in getfile(field_name, filenum)
#      24 # print("filename = ",filename)
#      25     #data = h5.File(filename, "r")
# ---> 26     data = osh5io.read_h5(filename)
#      27     #N = data['SIMULATION'].attrs['NX']
#      28     #axes = data['AXIS']
#
# ~/pyVisOS/osh5io.py in read_h5(filename, path, axis_name)
#     100     """
#     101     fname = filename if not path else path + '/' + filename
# --> 102     data_file = h5py.File(fname, 'r')
#     103
#     104     n_data = scan_hdf5_file_for_main_data_array(data_file)
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     442             with phil:
#     443                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 444                 fid = make_fid(name, mode, userblock_size,
#     445                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     446                                fs_persist=fs_persist, fs_threshold=fs_threshold),
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     197         if swmr and swmr_support:
#     198             flags |= h5f.ACC_SWMR_READ
# --> 199         fid = h5f.open(name, flags, fapl=fapl)
#     200     elif mode == 'r+':
#     201         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/scratch/agrt_root/agrt1/agrt/osiris/Mario_brute_force/MS/PHA/p1x1/ions//p1x1-ions-000100.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
species = 'electrons'
filenum =40
field = 'e2'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
#(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#data2 = osh5dir.getfile(field_name,filenum)

# %%
plt.figure(figsize=(14,14))
osh5vis.osplot(((data)), cmap = fldmap,aspect='equal',clim=(-0.08,0.08))
# Out:
# (<matplotlib.image.AxesImage at 0x14ee3d741c70>,
#  <matplotlib.colorbar.Colorbar at 0x14ee3d6d3eb0>)

# %%
osh5vis.osplot(data, cmap = fldmap)#,clim=(-0.01,0.01))
#plt.show()
#osh5vis.osplot(data2)#, cmap = fldmap,ylim = (-40,40),clim=(0,-7))
# Out:
# (<matplotlib.image.AxesImage at 0x2b3c63c3b490>,
#  <matplotlib.colorbar.Colorbar at 0x2b3c63c43890>)

# %%
species = 'electrons_O'
#filenum = 200
field = 'p1x1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log10(-data), cmap = fldmap)#,clim=(-0.1,0.1))

# %%
species = 'electrons_O'
filenum = 500
field = 'e1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(data, cmap = fldmap,clim=(-0.02,0.02))

# %%
species = 'protons'
filenum = 500
field = 'p2p1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log10(data), cmap = fldmap)#,clim = (0,0.01))#,xlim=(-0.2,0.2),ylim=(-0.2,0.2))

# %%
gamma2 = np.sum(data.data,1)

# %%
plt.plot(gamma)
plt.plot(gamma2)
plt.xlim((270,310))

# %%
x = np.linspace(-100,100,200)
plt.plot(x,np.heaviside(x+90,0.5)*np.heaviside(90-x,0.5))

# %%
field = 'e1'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data1 = osh5dir.getfile(field_name,filenum)
field = 'e2'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data2 = osh5dir.getfile(field_name,filenum)
data = np.sqrt(data1**2+data2**2)
plt.figure(figsize=(14,14))
osh5vis.osplot((data), cmap = fldmap,aspect='equal',clim=(-0.1,0.1))
# Out:
# (<matplotlib.image.AxesImage at 0x14ff7df21e80>,
#  <matplotlib.colorbar.Colorbar at 0x14ff7df341f0>)

# %%
base_directory = '/scratch/agrt_root/agrt1/agrt/osiris/Ryan_PA8'
osh5dir.runinfo(base_directory)
# Out:
# DENSITY
# PHA
# FLD

# %%
species = 'plasma'
filenum =5
field = 'e2'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
field = 'charge'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data2 = osh5dir.getfile(field_name,filenum)
species = 'driver'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data3 = osh5dir.getfile(field_name,filenum)
#(field_name,fldmap) = osh5dir.getfieldname(base_directory2,field,species,'')
#data2 = osh5dir.getfile(field_name,filenum)
plt.figure(figsize=(14,14))

osh5vis.osplot(-(data2))#, cmap = fldmap,aspect='equal')#,clim=(-0.02,0.02))
osh5vis.osplot(-(data3))#, cmap = fldmap,aspect='equal')#,clim=(-0.02,0.02))

osh5vis.osplot(-(data))#, cmap = fldmap,aspect='equal')#,clim=(-0.02,0.02))

# %%
Lz = 300
klist = 2*np.pi / Lz * np.arange(0,data.size)
datafft = abs(np.fft.fft(data)) / np.sqrt(data.size)

# %%
plt.plot(klist,datafft)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
field = 'p1x1'
filenum =220
species = 'driver'
(field_name,fldmap) = osh5dir.getfieldname(base_directory,field,species,'')
data = osh5dir.getfile(field_name,filenum)
osh5vis.osplot(np.log10(abs(data)))
# Out:
# /tmp/ipykernel_802563/4011123901.py:6: RuntimeWarning: divide by zero encountered in log10
#   osh5vis.osplot(np.log10(abs(data)))
# (<matplotlib.image.AxesImage at 0x149376ef3460>,
#  <matplotlib.colorbar.Colorbar at 0x149376eb7640>)
